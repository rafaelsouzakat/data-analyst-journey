# %%
import pandas as pd 
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)

df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@email.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
df
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 4    NaN      NaN                      NaN  NaN
# 5    NaN      NaN      Anonymous@email.com  NaN
# 6    NaN      NaN                      NaN  NaN

# %%
# dropna method
df.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
# these are the default arguments for this method
df.dropna(axis='index', how='all')
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 5    NaN      NaN      Anonymous@email.com  NaN

# %%
df.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df.dropna(axis='index', how='all', subset=['last', 'email'])

# this return all rows that have AT LEAST an email address or last name
# Out:
#    first     last                    email  age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com   33
# 1   Jane      Doe        JaneDoe@email.com   55
# 2   John      Doe        JohnDoe@email.com   63
# 3  Chris  Schafer                      NaN   36
# 5    NaN      NaN      Anonymous@email.com  NaN

# %% [markdown]
# ---
#
# How to handle custom missing values:
#
# Replace them with np.nan

# %%
# if we just want to see if values are missing without making any changes, we can use .isna() method
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object

# %% [markdown]
# ---
#
# When we have any NaN values on column that we're trying to convert to numbers, then we need to use the FLOAT dtype!

# %%
type(np.nan)
# Out:
# float

# %%
df['age'] = df['age'].astype(float)

# converting the 'age' column to float

# %%
df.dtypes
# Out:
# first        str
# last         str
# email        str
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# np.float64(46.75)
